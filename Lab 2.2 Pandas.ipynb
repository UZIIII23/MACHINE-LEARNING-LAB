# %% [markdown]
# 	AUTHOR:[UZAIR-UR-REHMAN]

# %% [markdown]
# ### Introduction To Pandas Module
# Here, we are learning data analysis. Pandas is a software library written for the Python programming language that helps with data manipulation and analysis. It offers various data structures which help in the manipulation of data. <br>
# One of the data structures used is DataFrame.<br>
# DataFrame is used as a way to store data in a rectangular grid.<br>
# Similar to how data is stored in Microsoft Excel.
# ### Installation
# We can easily install this library using the terminal. Follow the steps given below to install Pandas:<br>
# Step 1: Go to the Windows PowerShell.<br>
# Step 2: We can install pandas with the help of pip easily. Head over to the directory where you want to install the pandas and fire the below command:<br>
# __pip install pandas__<br>
# This is very simple to install.

# %%
# !pip install pandas

# %% [markdown]
# ### Other way to install
# If the above steps do not work for you, here is another way to install:<br>
# Step 1: Go to your browser. Search for __python unofficial binaries__, or click <br>
# https://www.lfd.uci.edu/~gohlke/pythonlibs/<br>
# and you will be redirected to the binary page.<br>
# Step 2: To download the library, search for pandas – Ctrl + F will help you. Download pandas library based on your python version. <br>
# Step 3: After the installation, head over to the directory where you've downloaded the pandas. <br>
# Step 4: Right-click to open Windows PowerShell. Pip can help us with the installation. Just go to that location in your terminal and run the following command: <br>
# __pip install pandas__ <br>
# Complete this command by the TAB button so that the location of your folder is mentioned.

# %% [markdown]
# ### import pandas
# Once Pandas is installed, import it in your applications by adding the import keyword:<br>
# __import pandas as pd__<br>
# Now Pandas is imported and ready to use.

# %%
import pandas

# %%
students = {
    'Name': ["Muhammad Ayub ", " Ibraheem khan", "Muhammad Abid", "Shumail Khan","Qasim Ali"],
    'Marks': [80, 72, 77, 65, 15],
    'Class':["1st Year", "2nd Year", "1st Year", "3rd Year", "2nd Year"],
    'Age': [20, 21, 19, 22, 21]
}

# %%
df = pandas.DataFrame(students)

# %%
df
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Pandas as pd
# Pandas is usually imported under the pd alias.
# #### alias:
# In Python alias are an alternate name for referring to the same thing.<br>
# Create an alias with the as keyword while importing:<br>
# __import pandas as pd__<br>
# Now the Pandas package can be referred to as pd instead of pandas.

# %%
import pandas as pd

# %%
df = pd.DataFrame(students)

# %%
df
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Checking Pandas Version
# The version string is stored under __version__ attribute.

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ## Saving to CSV and other extensions like excel

# %%
df.to_csv('pythonMonday.csv')

# %% [markdown]
# ## Remove Index and saving the csv file

# %%
df.to_csv('pythonMondayRemoveIndex.csv', index=False)

# %% [markdown]
# ## Show some rows from the Start

# %%
df.head()
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# ## Specify No of rows to show

# %%
df.head(3)
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19

# %%
df.tail(3)
# Out:
#             Name  Marks     Class  Age
# 2  Muhammad Abid     77  1st Year   19
# 3   Shumail Khan     65  3rd Year   22
# 4      Qasim Ali     15  2nd Year   21

# %%
df.tail()
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %%
df.describe()
# Out:
#            Marks        Age
# count   5.000000   5.000000
# mean   61.800000  20.600000
# std    26.771253   1.140175
# min    15.000000  19.000000
# 25%    65.000000  20.000000
# 50%    72.000000  21.000000
# 75%    77.000000  21.000000
# max    80.000000  22.000000

# %% [markdown]
# # Reading csv or other files

# %%
classData= pd.read_csv("pythonMondayRemoveIndex.csv")
classData
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %%
classData= pd.read_csv("pythonMonday.csv")
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData.drop('Name', axis=1)
# Out:
#    Unnamed: 0  Marks     Class  Age
# 0           0     80  1st Year   20
# 1           1     72  2nd Year   21
# 2           2     77  1st Year   19
# 3           3     65  3rd Year   22
# 4           4     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData.drop(0, axis=0)
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Check the spelling

# %%
classData['class']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 classData['class']
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'class'

# %% [markdown]
# # Check the trail space

# %%
classData['Class ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 classData['Class ']
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Class '

# %% [markdown]
# # Corrected Spelling

# %%
classData['Name']
# Out:
# First     Muhammad Ayub
# Second     Ibraheem khan
# Third      Muhammad Abid
# Fourth      Shumail Khan
# Fifth          Qasim Ali
# Name: Name, dtype: object

# %% [markdown]
# # Check the head space

# %%
classData[' Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 classData[' Name']
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: ' Name'

# %%
type(classData['Name'])
# Out:
# pandas.core.series.Series

# %%
classData['Age']
# Out:
# First     90
# Second    21
# Third     19
# Fourth    22
# Fifth      5
# Name: Age, dtype: int64

# %% [markdown]
# classData['gpa'][0]

# %%
classData['Age'][0]
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_5872\1100049511.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   classData['Age'][0]
# np.int64(90)

# %%
classData['Age'][0]=90
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_5872\883805414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData['Age'][0]=90
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_5872\883805414.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   classData['Age'][0]=90

# %%
classData
# Out:
#         Unnamed: 0            Name  Marks     Class  Age
# First            0  Muhammad Ayub      80  1st Year   90
# Second           1   Ibraheem khan     72  2nd Year   21
# Third            2   Muhammad Abid     77  1st Year   19
# Fourth           3    Shumail Khan     65  3rd Year   22
# Fifth            4       Qasim Ali     15  2nd Year    5

# %%
classData['Age'][4]
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_5872\3031961889.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   classData['Age'][4]
# np.int64(5)

# %%
classData['Age'][4]=5
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_5872\1411840039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData['Age'][4]=5
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_5872\1411840039.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   classData['Age'][4]=5

# %%
classData["Name"][4]
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_5872\106876926.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   classData["Name"][4]
# 'Qasim Ali'

# %% [markdown]
# # Rename the column name

# %%
classData.rename(columns={'Age': 'AGE'})
# Out:
#                   Name  Marks     Class  AGE
# First   Muhammad Ayub      80  1st Year   90
# Second   Ibraheem khan     72  2nd Year   21
# Third    Muhammad Abid     77  1st Year   19
# Fourth    Shumail Khan     65  3rd Year   22
# Fifth        Qasim Ali     15  2nd Year    5

# %% [markdown]
# ## Create Labels
# With the index argument, you can name your own labels.

# %%
classData.index = ["First","Second", "Third", "Fourth", "Fifth"]
classData
# Out:
#                   Name  Marks     Class  Age
# First   Muhammad Ayub      80  1st Year   90
# Second   Ibraheem khan     72  2nd Year   21
# Third    Muhammad Abid     77  1st Year   19
# Fourth    Shumail Khan     65  3rd Year   22
# Fifth        Qasim Ali     15  2nd Year    5

# %% [markdown]
# # Asignment

# %%
classdata = classData.drop('Unnamed: 0', axis=1)
classData
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 classdata = classData.drop('Unnamed: 0', axis=1)
#       2 classData
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %% [markdown]
# # Inplace

# %%
classData.drop('Unnamed: 0 , axis=1, inplace = True)
classData
# Out:
#   Cell In[96], line 1
#     classData.drop('Unnamed: 0 , axis=1, inplace = True)
#                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # Accessing the value in Dataframe

# %%
classData["Name"]
# Out:
# First     Muhammad Ayub
# Second     Ibraheem khan
# Third      Muhammad Abid
# Fourth      Shumail Khan
# Fifth          Qasim Ali
# Name: Name, dtype: object

# %%
classData["Name"]["Fifth"]
# Out:
# 'Qasim Ali'

# %% [markdown]
# ## Pandas
# Pandas is an open source data analysis library written in Python.<br>
# It uses the power and speed of numpy to make data analysis and preprocessing easy for data scientists.<br>
# __Pandas__ is used to analyze data.<br>
# Python data analysis using pandas is a great start to Exploratory Data Analysis (EDA) for a data scientist.

# %% [markdown]
# ## Pandas Data Structure
# Panda has two types of Data Structure:<br>
#     a) Series<br>
#     b) Dataframe
# ### Series
# It is a one dimentional array with indexes. It stores a single column or row of data in a Dataframe.<br>
# It is a one dimensional array capable of holding any type of data.
# ### Dataframe
# It is a tabular spreadsheet like structure representing rows each of which contains one or more columns.<br>
# It is a multi dimensional array capable of holding any type of data.<br>
# __Series__ is like a column, a __DataFrame__ is the whole table.

# %%
classData['Age']
# Out:
# First     90
# Second    21
# Third     19
# Fourth    22
# Fifth      5
# Name: Age, dtype: int64

# %%
 type(classData['Age'])
# Out:
# pandas.core.series.Series

# %%
classData
# Out:
#                   Name  Marks     Class  Age
# First   Muhammad Ayub      80  1st Year   90
# Second   Ibraheem khan     72  2nd Year   21
# Third    Muhammad Abid     77  1st Year   19
# Fourth    Shumail Khan     65  3rd Year   22
# Fifth        Qasim Ali     15  2nd Year    5

# %%
type(classData)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np

# %%
series1= pd.Series(np.random.rand())

# %%
series1
# Out:
# 0    0.458165
# dtype: float64

# %%
series1= pd.Series(np.random.rand(30))

# %%
series1
# Out:
# 0     0.134503
# 1     0.680832
# 2     0.006515
# 3     0.183679
# 4     0.144072
# 5     0.172714
# 6     0.671025
# 7     0.571739
# 8     0.218634
# 9     0.713035
# 10    0.509896
# 11    0.709901
# 12    0.450234
# 13    0.844310
# 14    0.981679
# 15    0.326488
# 16    0.065108
# 17    0.066862
# 18    0.494272
# 19    0.460146
# 20    0.961965
# 21    0.129325
# 22    0.964000
# 23    0.022344
# 24    0.759879
# 25    0.285745
# 26    0.257688
# 27    0.199612
# 28    0.553012
# 29    0.593606
# dtype: float64

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
np.random.rand(3,4)
# Out:
# array([[0.40796623, 0.30476143, 0.35422919, 0.33318236],
#        [0.9200891 , 0.16900838, 0.56542047, 0.89527311],
#        [0.36958754, 0.71346798, 0.44430584, 0.17000809]])

# %%
newDf = pd.DataFrame(np.random.rand(330,5))
# newDf = pd.DataFrame(np.random.rand(330,5), index=np.arange(330))

# %%
type(newDf)
# Out:
# pandas.core.frame.DataFrame

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0  0.958931  0.322317  0.807322  0.662083  0.143866
# 1  0.284018  0.514254  0.956308  0.959290  0.475805

# %%
newDf.tail(2)
# Out:
#             0         1         2         3         4
# 328  0.872989  0.282196  0.088248  0.043008  0.745898
# 329  0.208471  0.520747  0.933263  0.531863  0.749657

# %%
newDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       330 non-null    float64
#  1   1       330 non-null    float64
#  2   2       330 non-null    float64
#  3   3       330 non-null    float64
#  4   4       330 non-null    float64
# dtypes: float64(5)
# memory usage: 13.0 KB

# %%
newDf.describe()
# Out:
#                 0           1           2           3           4
# count  330.000000  330.000000  330.000000  330.000000  330.000000
# mean     0.516130    0.497043    0.493391    0.498942    0.501222
# std      0.283950    0.278169    0.292492    0.288466    0.286690
# min      0.000473    0.005861    0.017326    0.002265    0.002794
# 25%      0.283135    0.272958    0.225212    0.256265    0.262647
# 50%      0.509050    0.478329    0.501209    0.511497    0.506380
# 75%      0.770906    0.727921    0.734686    0.740968    0.759746
# max      0.999876    0.999428    0.999977    0.999402    0.995879

# %%
newDf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %% [markdown]
# # Change the value inside the dataframe

# %%
newDf[0][0]= 10000.0
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_5872\1615845312.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDf[0][0]= 10000.0

# %%
newDf
# Out:
#                 0         1         2         3         4
# 0    10000.000000  0.322317  0.807322  0.662083  0.143866
# 1        0.284018  0.514254  0.956308  0.959290  0.475805
# 2        0.317915  0.767033  0.672415  0.663340  0.874070
# 3        0.531814  0.635788  0.278465  0.509269  0.808176
# 4        0.529390  0.783149  0.715442  0.811960  0.457492
# ..            ...       ...       ...       ...       ...
# 325      0.027332  0.666433  0.136372  0.996368  0.456579
# 326      0.905416  0.296188  0.098491  0.212634  0.452388
# 327      0.923053  0.800407  0.051468  0.510665  0.927859
# 328      0.872989  0.282196  0.088248  0.043008  0.745898
# 329      0.208471  0.520747  0.933263  0.531863  0.749657
#
# [330 rows x 5 columns]

# %%
newDf.head()
# Out:
py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDfView[0][0]=765

# %%
newDf.head()
# Out:
#             0         1         2         3         4
# 0  765.000000  0.322317  0.807322  0.662083  0.143866
# 1    0.284018  0.514254  0.956308  0.959290  0.475805
# 2    0.317915  0.767033  0.672415  0.663340  0.874070
# 3    0.531814  0.635788  0.278465  0.509269  0.808176
# 4    0.529390  0.783149  0.715442  0.811960  0.457492

# %%
newDfView.head()
# Out:
#             0         1         2         3         4
# 0  765.000000  0.322317  0.807322  0.662083  0.143866
# 1    0.284018  0.514254  0.956308  0.959290  0.475805
# 2    0.317915  0.767033  0.672415  0.663340  0.874070
# 3    0.531814  0.635788  0.278465  0.509269  0.808176
# 4    0.529390  0.783149  0.715442  0.811960  0.457492

# %%
newDfCopy=newDf.copy()

# %%
newDfCopy[0][0]=656
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_5872\2532441962.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDfCopy[0][0]=656

# %%
newDf.head()
# Out:
#             0         1         2         3         4
# 0  765.000000  0.322317  0.807322  0.662083  0.143866
# 1    0.284018  0.514254  0.956308  0.959290  0.475805
# 2    0.317915  0.767033  0.672415  0.663340  0.874070
# 3    0.531814  0.635788  0.278465  0.509269  0.808176
# 4    0.529390  0.783149  0.715442  0.811960  0.457492

# %%
newDfCopy.head()
# Out:
#             0         1         2         3         4
# 0  656.000000  0.322317  0.807322  0.662083  0.143866
# 1    0.284018  0.514254  0.956308  0.959290  0.475805
# 2    0.317915  0.767033  0.672415  0.663340  0.874070
# 3    0.531814  0.635788  0.278465  0.509269  0.808176
# 4    0.529390  0.783149  0.715442  0.811960  0.457492

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    "Student": ["Ali", "Sara", "Bilal", "Hina"],
    "Marks": [85, 92, 76, 89],
    "Age": [20, 21, 19, 22]
}

df = pd.DataFrame(data)
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#    Student  Marks  Age
# 0     Ali     85   20
# 1    Sara     92   21
# 2   Bilal     76   19
# 3    Hina     89   22

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  4 non-null      object
#  1   Marks    4 non-null      int64
#  2   Age      4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes
# None

# %%
print("\nDescribe:\n", df.describe())
# Out:
# Describe:
#             Marks        Age
# count   4.000000   4.000000
# mean   85.500000  20.500000
# std     6.952218   1.290994
# min    76.000000  19.000000
# 25%    82.750000  19.750000
# 50%    87.000000  20.500000
# 75%    89.750000  21.250000
# max    92.000000  22.000000

# %%
# -----------------------------
# 2. SORTING
# -----------------------------
print("\nSorting by Marks (descending):\n", df.sort_values("Marks", ascending=False))
print("\nSorting by Age (ascending):\n", df.sort_values("Age"))
# Out:
# Sorting by Marks (descending):
#    Student  Marks  Age
# 1    Sara     92   21
# 3    Hina     89   22
# 0     Ali     85   20
# 2   Bilal     76   19
#
# Sorting by Age (ascending):
#    Student  Marks  Age
# 2   Bilal     76   19
# 0     Ali     85   20
# 1    Sara     92   21
# 3    Hina     89   22

# %%
# -----------------------------
# 3. TRANSPOSE
# -----------------------------
print("\nTransposed DataFrame:\n", df.T)
# Out:
# Transposed DataFrame:
#             0     1      2     3
# Student  Ali  Sara  Bilal  Hina
# Marks     85    92     76    89
# Age       20    21     19    22

# %% [markdown]
# ## Slicing through loc function

# %%
import pandas as pd

# Sample DataFrame
data = {
    "Name": ["Ali", "Sara", "Bilal", "Hina"],
    "Marks": [85, 92, 76, 89],
    "Age": [20, 21, 19, 22]
}

df = pd.DataFrame(data)
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#      Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
# 1. Select row with label 2
print(df.loc[2])
# Out:
# Name     Bilal
# Marks       76
# Age         19
# Name: 2, dtype: object

# %%
# 2. Select specific rows and columns by NAME
print(df.loc[1:3, ["Name", "Marks"]])
# Out:
#     Name  Marks
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
# 3. Applying Filter: Conditional selection: students with Marks > 85
print(df.loc[df["Marks"] > 85])
# Out:
#    Name  Marks  Age
# 1  Sara     92   21
# 3  Hina     89   22

# %% [markdown]
# ##  Slicing through iloc

# %%
df
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
# 1. Select row at index 0
print(df.iloc[0])
# Out:
# Name     Ali
# Marks     85
# Age       20
# Name: 0, dtype: object

# %%
# 2. Select 2 rows and 2 columns by position
print(df.iloc[0:2, 0:2])
# Out:
#    Name  Marks
# 0   Ali     85
# 1  Sara     92

# %%
# 3. Select last row using negative index
print(df.iloc[-1])
# Out:
# Name     Hina
# Marks      89
# Age        22
# Name: 3, dtype: object

# %% [markdown]
# # Dropping the Row

# %%
df
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
df.drop(0).head()
# Out:
#     Name  Marks  Age
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %% [markdown]
# # Dropping the col

# %%
df.drop(['Age'], axis=1).head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.head()
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
df.drop(['Age'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.reset_index().head()
# Out:
#    index   Name  Marks
# 0      0    Ali     85
# 1      1   Sara     92
# 2      2  Bilal     76
# 3      3   Hina     89

# %%
df.reset_index(drop=True).head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %% [markdown]
# # Groupby
# The groupby method allows you to group rows of data together and call aggregate functions
#
# ​
# ​

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ### Now you can use the .groupby() method to group rows together based off of a column name.
# For instance let's group based off of Company. This will create a DataFrameGroupBy object:

# %%
df.groupby('Company')

# %% [markdown]
# ##### You can save this object as a new variable:

# %%
by_comp = df.groupby("Company")
type(by_comp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# #### And then call aggregate methods of the object:

# %%
by_comp.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2460, in GroupBy.mean.<locals>.<lambda>(x)
#    2457 else:
#    2458     result = self._cython_agg_general(
#    2459         "mean",
# -> 2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)   6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'CarlSarah' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 by_comp.mean()
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2458, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2451     return self._numba_agg_general(
#    2452         grouped_mean,
#    2453         executor.float_dtype_mapping,
#    2454         engine_kwargs,
#    2455         min_periods=0,
#    2456     )
#    2457 else:
# -> 2458     result = self._cython_agg_general(
#    2459         "mean",
#    2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2004, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2001     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002     return result
# -> 2004 new_mgr = data.grouped_reduce(array_func)
#    2005 res = self._wrap_agged_manager(new_mgr)
#    2006 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2001, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1998     return result
#    2000 assert alt is not None
# -> 2001 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002 return result
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:1947, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1945     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1946     # preserve the kind of exception that raised
# -> 1947     raise type(err)(msg) from err
#    1949 dtype = ser.dtype
#    1950 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
df.groupby('Company').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2460, in GroupBy.mean.<locals>.<lambda>(x)
#    2457 else:
#    2458     result = self._cython_agg_general(
#    2459         "mean",
# -> 2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)   6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'CarlSarah' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 df.groupby('Company').mean()
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2458, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2451     return self._numba_agg_general(
#    2452         grouped_mean,
#    2453         executor.float_dtype_mapping,
#    2454         engine_kwargs,
#    2455         min_periods=0,
#    2456     )
#    2457 else:
# -> 2458     result = self._cython_agg_general(
#    2459         "mean",
#    2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2004, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2001     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002     return result
# -> 2004 new_mgr = data.grouped_reduce(array_func)
#    2005 res = self._wrap_agged_manager(new_mgr)
#    2006 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2001, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1998     return result
#    2000 assert alt is not None
# -> 2001 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002 return result
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:1947, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1945     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1946     # preserve the kind of exception that raised
# -> 1947     raise type(err)(msg) from err
#    1949 dtype = ser.dtype
#    1950 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
by_comp.std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 by_comp.std()
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2647, in GroupBy.std(self, ddof, engine, engine_kwargs, numeric_only)
#    2637     return np.sqrt(
#    2638         self._numba_agg_general(
#    2639             grouped_var,
#    (...)   2644         )
#    2645     )
#    2646 else:
# -> 2647     return self._cython_agg_general(
#    2648         "std",
#    2649         alt=lambda x: Series(x, copy=False).std(ddof=ddof),
#    2650         numeric_only=numeric_only,
#    2651         ddof=ddof,
#    2652     )
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:2004, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2001     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002     return result
# -> 2004 new_mgr = data.grouped_reduce(array_func)
#    2005 res = self._wrap_agged_manager(new_mgr)
#    2006 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\groupby.py:1979, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1977 def array_func(values: ArrayLike) -> ArrayLike:
#    1978     try:
# -> 1979         result = self._grouper._cython_operation(
#    1980             "aggregate",
#    1981             values,
#    1982             how,
#    1983             axis=data.ndim - 1,
#    1984             min_count=min_count,
#    1985             **kwargs,
#    1986         )
#    1987     except NotImplementedError:
#    1988         # generally if we have numeric_only=False
#    1989         # and non-applicable functions
#    1990         # try to python agg
#    1991         # TODO: shouldn't min_count matter?
#    1992         # TODO: avoid special casing SparseArray here
#    1993         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\ops.py:831, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     829 ids, _, _ = self.group_info
#     830 ngroups = self.ngroups
# --> 831 return cy_op.cython_operation(
#     832     values=values,
#     833     axis=axis,
#     834     min_count=min_count,
#     835     comp_ids=ids,
#     836     ngroups=ngroups,
#     837     **kwargs,
#     838 )
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\ops.py:550, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     539 if not isinstance(values, np.ndarray):
#     540     # i.e. ExtensionArray
#     541     return values._groupby_op(
#     542         how=self.how,
#     543         has_dropped_na=self.has_dropped_na,
#    (...)    547         **kwargs,
#     548     )
# --> 550 return self._cython_op_ndim_compat(
#     551     values,
#     552     min_count=min_count,
#     553     ngroups=ngroups,
#     554     comp_ids=comp_ids,
#     555     mask=None,
#     556     **kwargs,
#     557 )
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\ops.py:344, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     341     # otherwise we have OHLC
#     342     return res.T
# --> 344 return self._call_cython_op(
#     345     values,
#     346     min_count=min_count,
#     347     ngroups=ngroups,
#     348     comp_ids=comp_ids,
#     349     mask=mask,
#     350     result_mask=result_mask,
#     351     **kwargs,
#     352 )
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\ops.py:402, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     400 out_shape = self._get_output_shape(ngroups, values)
#     401 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
# --> 402 values = self._get_cython_vals(values)
#     403 out_dtype = self._get_out_dtype(values.dtype)
#     405 result = maybe_fill(np.empty(out_shape, dtype=out_dtype))
#
# File c:\Users\PMLS\anaconda3\envs\DSP\Lib\site-packages\pandas\core\groupby\ops.py:230, in WrappedCythonOp._get_cython_vals(self, values)
#     224 how = self.how
#     226 if how in ["median", "std", "sem", "skew"]:
#     227     # median only has a float64 implementation
#     228     # We should only get here with is_numeric, as non-numeric cases
#     229     #  should raise in _get_cython_function
# --> 230     values = ensure_float64(values)
#     232 elif values.dtype.kind in "iu":
#     233     if how in ["var", "mean"] or (
#     234         self.kind == "transform" and self.has_dropped_na
#     235     ):
#     236         # has_dropped_na check need for test_null_group_str_transformer
#     237         # result may still include NaN, so we have to cast
#
# File pandas/_libs/algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'Sam'

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0
